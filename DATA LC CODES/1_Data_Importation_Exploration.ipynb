# %% [markdown]
# ## INSTALLING NECESSARY LIBRARIES ##
# 1. PANDAS
# 2. NUMPY

# %%
import pandas as pd #Imports datasets (e.g. excels, csv)

# %%
import numpy as numpy #Supports pandas imports datasets in a tabular format

# %%
#Comment
import pandas

# %% [markdown]
# Installing pandas and numpy for the first time

# %%
# !pip install pandas

# %%
#After installation, call up the library
import pandas

# %% [markdown]
# ## INSTALLING LIBRARIES FOR THE FIRST TIME ##

# %%
# !pip install pandas
# !pip install numpy

# %%
# After installation, then import the libraries of the installed packages
import pandas as pd

import numpy as numpy

# %% [markdown]
# IMPORTING DATASETS

# %%
#Importing an excel
pd.read_excel("DiamondPricesData.xlsx")
# Out:
#        price  carat        cut color clarity  depth  table     x     y     z
# 0        326   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1        326   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2        327   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3        334   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4        335   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   2757   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   2757   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   2757   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   2757   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#Turn my imported dataset in to a python dataframe
diamonds = pd.read_excel("DiamondPricesData.xlsx")

#View the imported dataframe
diamonds.head(5)
# Out:
#    price  carat      cut color clarity  depth  table     x     y     z
# 0    326   0.23    Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1    326   0.21  Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2    327   0.23     Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3    334   0.29  Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4    335   0.31     Good     J     SI2   63.3   58.0  4.34  4.35  2.75

# %%
diamonds
# Out:
#        price  carat        cut color clarity  depth  table     x     y     z
# 0        326   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1        326   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2        327   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3        334   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4        335   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   2757   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   2757   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   2757   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   2757   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#Import csv file
politicians = pd.read_csv("Female_Mps.csv")

#View the top three rows of the dattaframe
politicians.head(3)
# Out:
#        country  1945  1946  1947  1948  1949  1950  1951  1952  1953  ...  \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1       Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      Albania  3.66  6.46  8.81  10.8  12.5  14.1  13.5  12.9  12.4  ...
#
#    2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0  27.4  27.4  27.4  27.4  27.7  27.8  27.9  27.2  27.2  27.2
# 1  34.1  33.5  32.8  32.2  31.6  30.9  30.4  30.0  29.6  29.6
# 2  15.9  15.7  18.8  21.8  24.8  27.9  28.6  29.5  29.5  35.7
#
# [3 rows x 78 columns]

# %%
#View the entire dataset of politicians
politicians
# Out:
#                             country  1945  1946  1947   1948   1949   1950  \
# 0                       Afghanistan   NaN   NaN   NaN    NaN    NaN    NaN
# 1                            Angola   NaN   NaN   NaN    NaN    NaN    NaN
# 2                           Albania  3.66  6.46  8.81  10.80  12.50  14.10
# 3                           Andorra   NaN   NaN   NaN    NaN    NaN    NaN
# 4              United Arab Emirates   NaN   NaN   NaN    NaN    NaN    NaN
# ..                              ...   ...   ...   ...    ...    ...    ...
# 179                          Uganda   NaN   NaN   NaN    NaN    NaN    NaN
# 180                         Ukraine   NaN   NaN   NaN    NaN    NaN    NaN
# 181  St. Vincent and the Grenadines   NaN   NaN   NaN    NaN    NaN    NaN
# 182                           Samoa   NaN   NaN   NaN    NaN    NaN    NaN
# 183                    South Africa   NaN   NaN   NaN   1.31   1.43   1.54
#
# ...

# %%
#importing an spss dataset
dec = pd.read_spss("Dec11.sav")

# %%
#View the imported spss data
dec
# Out:
#         psraid  int_date     lang    sample               segment  strata  \
# 0     100017.0  120611.0  English  Landline    RDD landline (18+)     8.0
# 1     100023.0  120611.0  English  Landline    RDD landline (18+)     3.0
# 2     100026.0  120711.0  English  Landline    RDD landline (18+)     6.0
# 3     100027.0  120611.0  English  Landline    RDD landline (18+)     7.0
# 4     100031.0  121011.0  English  Landline    RDD landline (18+)    10.0
# ...        ...       ...      ...       ...                   ...     ...
# 2043  201694.0  121111.0  English      Cell  RDD cell phone (18+)     6.0
# 2044  203329.0  121411.0  English      Cell  RDD cell phone (18+)     9.0
# 2045  204682.0  121711.0  English      Cell  RDD cell phone (18+)    10.0
# 2046  101739.0  121211.0  English  Landline    RDD landline (18+)     6.0
# 2047  200545.0  120711.0  English      Cell  RDD cell phone (18+)     6.0
#
#               version           state    cregion  density  ...  \
# ...

# %%
#If there's an issue with pandas importing spss, we use a different libbrary called pyreadstat
# !pip install pyreadstat
import pyreadstat as py
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Use the pyreadstat to import the spss data
dec2, meta = py.read_sav("Dec11.sav")

#view if the data is imported correctly
dec2
# Out:
#         psraid  int_date  lang  sample  segment  strata  version  state  \
# 0     100017.0  120611.0   1.0     1.0      1.0     8.0      1.0   48.0
# 1     100023.0  120611.0   1.0     1.0      1.0     3.0      1.0   36.0
# 2     100026.0  120711.0   1.0     1.0      1.0     6.0      1.0    1.0
# 3     100027.0  120611.0   1.0     1.0      1.0     7.0      1.0   17.0
# 4     100031.0  121011.0   1.0     1.0      1.0    10.0      1.0   45.0
# ...        ...       ...   ...     ...      ...     ...      ...    ...
# 2043  201694.0  121111.0   1.0     2.0      2.0     6.0      1.0   10.0
# 2044  203329.0  121411.0   1.0     2.0      2.0     9.0      1.0   36.0
# 2045  204682.0  121711.0   1.0     2.0      2.0    10.0      1.0   36.0
# 2046  101739.0  121211.0   1.0     1.0      1.0     6.0      1.0   47.0
# 2047  200545.0  120711.0   1.0     2.0      2.0     6.0      1.0   26.0
#
#       cregion  density  ... ideo3x iphoneuse  hphoneuse  adults  recadults  \
# ...

# %% [markdown]
# ## HOW DOES THE DATASET LOOK (DEFINING DATA TYPES) ##

# %%
# Looking at the diamonds dataframe
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   price    53940 non-null  int64
#  1   carat    53940 non-null  float64
#  2   cut      53940 non-null  object
#  3   color    53934 non-null  object
#  4   clarity  53940 non-null  object
#  5   depth    53926 non-null  float64
#  6   table    53940 non-null  float64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
# Check the descriptive statistics
diamonds.describe()
# Out:
#               price         carat         depth         table             x  \
# count  53940.000000  53940.000000  53926.000000  53940.000000  53940.000000
# mean    3932.799722      0.797940     61.749479     57.457184      5.731157
# std     3989.439738      0.474011      1.432661      2.234491      1.121761
# min      326.000000      0.200000     43.000000     43.000000      0.000000
# 25%      950.000000      0.400000     61.000000     56.000000      4.710000
# 50%     2401.000000      0.700000     61.800000     57.000000      5.700000
# 75%     5324.250000      1.040000     62.500000     59.000000      6.540000
# max    18823.000000      5.010000     79.000000     95.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
dec.describe()
# Out:
#               psraid       int_date       strata          smsa          wt1  \
# count    2048.000000    2048.000000  2048.000000   2048.000000  2048.000000
# mean   197937.231445  121242.689453     6.019531  22199.189453     1.004148
# std     90301.769278     357.208792     3.457695  16078.422135     1.054763
# min    100017.000000  120611.000000     0.000000      0.000000     0.204957
# 25%    102292.750000  121011.000000     3.000000      0.000000     0.575831
# 50%    201676.500000  121311.000000     7.000000  25240.000000     0.595351
# 75%    203969.000000  121511.000000     9.000000  35620.000000     0.893026
# max    400471.000000  121911.000000    10.000000  49740.000000     7.096579
#
#              pupsa          wt2       weight
# count  2048.000000  2048.000000  2048.000000
# mean      0.967304     0.969078     4.490674
# std       0.539025     1.243045     3.907900
# min       0.628436     0.128802     1.000000
# 25%       0.774818     0.446164     1.900000
# ...

# %%
# Looking at descriptive stats of only one variable
diamonds["price"].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
#Checking one particular descriptive stat (e.g. median)
diamonds.median()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10012\3468700131.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   diamonds.median()
# price    2401.00
# carat       0.70
# depth      61.80
# table      57.00
# x           5.70
# y           5.71
# z           3.53
# dtype: float64

# %%
# Forcing python to give descriptive stats about "object" or "string" data
import numpy as np
diamonds.describe(include=object)
# Out:
#           cut  color clarity
# count   53940  53934   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11286   13065

# %% [markdown]
# ## DATA TRANSFORMATION/ CLEANING / WRANGLING ##

# %%
#Check for missing information (null)
politicians.isna()
# Out:
#      country   1945   1946   1947   1948   1949   1950   1951   1952   1953  \
# 0      False   True   True   True   True   True   True   True   True   True
# 1      False   True   True   True   True   True   True   True   True   True
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False   True   True   True   True   True   True   True   True   True
# 4      False   True   True   True   True   True   True   True   True   True
# ..       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 179    False   True   True   True   True   True   True   True   True   True
# 180    False   True   True   True   True   True   True   True   True   True
# 181    False   True   True   True   True   True   True   True   True   True
# 182    False   True   True   True   True   True   True   True   True   True
# 183    False   True   True   True  False  False  False  False  False  False
#
# ...

# %%
#Count the number of missing information
politicians.isna().sum()
# Out:
# country      0
# 1945       167
# 1946       150
# 1947       144
# 1948       136
#           ...
# 2017         9
# 2018         9
# 2019         1
# 2020         2
# 2021         2
# Length: 78, dtype: int64
