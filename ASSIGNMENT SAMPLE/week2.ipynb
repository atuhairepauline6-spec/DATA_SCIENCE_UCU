# %%
import pandas as pd

# %%
import numpy as numpy

# %%
pd.read_excel("Vegetable_Sales.xlsx")
# Out:
#            Item Code                                     Item Name  \
# 0    102900000000000                              Niushou Shengcai
# 1    102900000000000                             Sichuan Red Cedar
# 2    102900000000000                      Xixia Black Mushroom (1)
# 3    102900000000000                         Local Xiaomao Cabbage
# 4    102900000000000                                  White Caitai
# ..               ...                                           ...
# 246  106972000000000                    Haixian Mushroom (Bag) (3)
# 247  106972000000000                          Xianzongye (Bag) (2)
# 248  106973000000000                          Xianzongye (Bag) (3)
# 249  106973000000000  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106974000000000                 Hfyg Haixian Mushroom (Bunch)
#
#      Loss Rate (%)  Wholesale Price ($/kg)  Quantity Sold (kg)  \
# 0             4.39                    3.88               0.396
# ...

# %%
#Turn my imported dataset in to a python dataframe
vegetables = pd.read_excel("Vegetable_Sales.xlsx")

#View the imported dataframe
vegetables.head(5)
# Out:
#          Item Code                 Item Name  Loss Rate (%)  \
# 0  102900000000000          Niushou Shengcai           4.39
# 1  102900000000000         Sichuan Red Cedar          10.46
# 2  102900000000000  Xixia Black Mushroom (1)          10.80
# 3  102900000000000     Local Xiaomao Cabbage           0.18
# 4  102900000000000              White Caitai           8.78
#
#    Wholesale Price ($/kg)  Quantity Sold (kg)  Unit Selling Price ($/kg)  \
# 0                    3.88               0.396                        7.6
# 1                    6.72               0.849                        3.2
# 2                    3.19               0.409                        7.6
# 3                    9.24               0.421                       10.0
# 4                    7.03               0.539                        8.0
#
#   Sale or Return Discount (Yes/No)
# 0           sale                No
# 1           sale                No
# 2           sale                No
# ...

# %%
#Variables to For Variables and Observation

vegetables.describe()
# Out:
#           Item Code  Loss Rate (%)  Wholesale Price ($/kg)  \
# count  2.510000e+02     251.000000              251.000000
# mean   1.031908e+14       9.426693                6.277251
# std    1.048439e+12       5.211027                3.515870
# min    1.029000e+14       0.000000                1.460000
# 25%    1.029000e+14       8.225000                4.095000
# 50%    1.029000e+14       9.430000                5.610000
# 75%    1.029000e+14      11.130000                7.855000
# max    1.069740e+14      29.250000               29.540000
#
#        Quantity Sold (kg)  Unit Selling Price ($/kg)
# count          251.000000                 251.000000
# mean             0.413518                   9.635857
# std              0.208310                   5.200230
# min              0.031000                   3.200000
# 25%              0.256000                   6.000000
# 50%              0.401000                   8.000000
# 75%              0.502000                  10.000000
# ...

# %%
#View the Sample
vegetables["Item Code"].describe()
# Out:
# count    2.510000e+02
# mean     1.031908e+14
# std      1.048439e+12
# min      1.029000e+14
# 25%      1.029000e+14
# 50%      1.029000e+14
# 75%      1.029000e+14
# max      1.069740e+14
# Name: Item Code, dtype: float64

# %%
#View the Observation
vegetables["Quantity"].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\AA\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Quantity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 #View the Observation
# ...
