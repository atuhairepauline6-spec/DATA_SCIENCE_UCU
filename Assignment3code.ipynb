# %%
 # %pip install gymnasium
 # %pip install stable-baselines3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 # %pip install highway-env
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# filename: train_agent.py

import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import CheckpointCallback

# %%
# Configuration
MODEL_SAVE_PATH = "./trained_model/dqn_traffic_controller.zip"
LOG_DIR = "./logs/"
TIMESTEPS = 100000

# %%
from stable_baselines3.common.env_util import make_vec_env

# %%
# %pip install gym-sumo
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      -------------- ------------------------- 262.1/721.7 kB ? eta -:--:--
#      --------------------------- ---------- 524.3/721.7 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 721.7/721.7 kB 1.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827741 sha256=29d79088a492ad456a9cfb86660dab6f4e4045902c160f699d2af62b68c777d3
# ...

# %%
import highway_env

# %%
from stable_baselines3.common.env_util import make_vec_env

# %%
env = make_vec_env("intersection-v1", n_envs=1)

# %%
# 1. Environment Setup
# We use a vectorized environment for efficiency
# 'intersection-v0' is a standard Gymnasium envi0ronment included in highway-env

env_id = "sumo-Intersection-v0"
env = make_vec_env("intersection-v1", n_envs=1)

# %%
from stable_baselines3 import DQN

# %%
print(env.action_space)
# Out:
# Box(-1.0, 1.0, (2,), float32)

# %%
from stable_baselines3 import SAC

# %%
# 1. Define the Environment Wrapper (Fix for Continuous Action Space)

def make_env_wrapper(env_id: str):
    pass

# %%
# %pip install gym
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 # Creates the environment and applies the DiscreteActionWrapper,which is REQUIRED for DQN to work with intersection-v1.


env = gym.make('CartPole-v1')

# %%
# We define 2 discrete actions: 0=Keep Phase,1=Change Phase.
# make_vec_env will handle the gym .make call internally 


def make_env_wrapper(env_id: str):
    env = gym.make(env_id)
    env = gym.wrappers.DiscreteActionWrapper(env, [0, 1])
    return env

# %%
# 2. Environment Setup (Using the Lambda Factory Function)

lambda: create_wrapped_env(), 
n_envs=1, # Running with a single environment for simplicity
seed=42 # Set a seed for reproducibility

# %%
print(f"Environment Setup Complete. Action Space: {env.action_space}")
# Out:
# Environment Setup Complete. Action Space: Discrete(2)

# %%
from stable_baselines3 import DQN

# %%
LOG_DIR="logs/"
tensorboard_log="LOG_DIR"

# %%
# %pip install shimmy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 3. Algorithm Initialization (DQN Hyperparameters)
# MlpPolicy is the neural network type (Multi-layer Perceptron)
model = DQN("MlpPolicy", 
            env, 
            learning_rate=1e-3, 
            buffer_size=10000, 
            learning_starts=1000, 
            batch_size=32, 
            gamma=0.99, # Discount factor
            train_freq=4, 
            target_update_interval=1000, 
            tensorboard_log=LOG_DIR, 
            verbose=1)
# Out:
# Using cpu device
# c:\Users\AA\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# %pip install pytorch-lightning
# Out:
# ...
#    ---------------------------------------- 0.0/831.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/831.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/831.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/831.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/831.6 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/831.6 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/831.6 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/831.6 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/831.6 kB ? eta -:--:--
#    ----------------------- -------------- 524.3/831.6 kB 303.2 kB/s eta 0:00:02
#    ----------------------- -------------- 524.3/831.6 kB 303.2 kB/s eta 0:00:02
#    ----------------------- -------------- 524.3/831.6 kB 303.2 kB/s eta 0:00:02
#    ----------------------------------- -- 786.4/831.6 kB 318.5 kB/s eta 0:00:01
# ...

# %%
# 4. Model Saving & Checkpoint Callback
from pytorch_lightning.callbacks import ModelCheckpoint

# %%
checkpoint_callback = ModelCheckpoint(
dirpath='.',
filename='dqn_checkpoint_{epoch}',
every_n_train_steps=5000
)

# %%
from stable_baselines3 import DQN; model =DQN("MlpPolicy",env)
# Out:
# c:\Users\AA\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
import gymnasium as gym
from stable_baselines3 import DQN

env = gym.make("CartPole-v1")
model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.5     |
# |    ep_rew_mean      | 28.5     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 114      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 114      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.52     |
# |    n_updates        | 3        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 124      |
# |    time_elapsed     | 1        |
# ...

# %%
# 5. Training
print(f"\nStarting training for 1000 timesteps...")
# Out:
# Starting training for 1000 timesteps...

# %%
from stable_baselines3.common.callbacks import CheckpointCallback
checkpoint_callback = CheckpointCallback(
       save_freq=1000,
       save_path='./logs/',
       name_prefix='rl_model',
       verbose=1,
   )

# %%
TIMESTEPS = 1000
model.learn(total_timesteps=TIMESTEPS, callback=checkpoint_callback)
print("Training finished.")
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 118      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 63       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 97       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 132      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.296    |
# |    n_updates        | 2482     |
# ----------------------------------
# ----------------------------------
# ...

# %%
# 6. Final Model Serialization
MODEL_SAVE_PATH ="C:\\Users\\AA\\Desktop\\DLC ASSIGNMENT2"

# %%
model.save(MODEL_SAVE_PATH)
# print(f"Model saved to: {MODEL_SAVE_PATH}")

# env.close()

# %%
env.close()

# %%
# %pip install fastapi
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [starlette]
#    ------------- -------------------------- 1/3 [starlette]
#    ------------- -------------------------- 1/3 [starlette]
#    ------------- -------------------------- 1/3 [starlette]
#    -------------------------- ------------- 2/3 [fastapi]
#    -------------------------- ------------- 2/3 [fastapi]
#    -------------------------- ------------- 2/3 [fastapi]
#    -------------------------- ------------- 2/3 [fastapi]
#    -------------------------- ------------- 2/3 [fastapi]
#    ---------------------------------------- 3/3 [fastapi]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script fastapi.exe is installed in 'c:\Users\AA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
#Part 2: Model serving (Interface API)


#filename: api_server.py

from fastapi import FastAPI
from pydantic import BaseModel
from stable_baselines3 import DQN
import numpy as np
import os
